# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append("../library")
import RecSys as rs
path = "../clean_data/"

# %%
chefmozGeo_r = pd.read_csv(path + "chefmozGeo_r.csv", sep=';').drop(['Unnamed: 0'],axis=1)
chefmozProfile_r = pd.read_csv(path + "chefmozProfile_r.csv", sep=';').drop(['Unnamed: 0'],axis=1)
rating_final_r = pd.read_csv(path + "rating_final_r.csv", sep=';').drop(['Unnamed: 0'],axis=1)
userChefmozRelation_r = pd.read_csv(path + "userChefmozRelation_r.csv", sep=';').drop(['Unnamed: 0'],axis=1)
userGeo_r = pd.read_csv(path + "userGeo_r.csv", sep=';').drop(['Unnamed: 0'],axis=1)
userProfile_r = pd.read_csv(path + "userProfile_r.csv", sep=';').drop(['Unnamed: 0'],axis=1)

# %%
chefmozGeo_r.head()
# Out:
#    placeID   latitude   longitude  \
# 0   134999  18.915421  -99.184871
# 1   132825  22.147392 -100.983092
# 2   135106  22.149709 -100.976093
# 3   132667  23.752697  -99.163359
# 4   132613  23.752903  -99.165076
#
#                                       the_geom_meter  \
# 0  0101000020957F000088568DE356715AC138C0A525FC46...
# 1  0101000020957F00001AD016568C4858C1243261274BA5...
# 2  0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3  0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4  0101000020957F00008EBA2D06DC8157C194E03B7B504E...
#
#                                   address             city            state  \
# 0                              Revolucion       Cuernavaca          Morelos
# 1  esquina santos degollado y leon guzman           s.l.p.           s.l.p.
# 2                         Universidad 169  San Luis Potosi  San Luis Potosi
# 3                 calle emilio portes gil        victoria        tamaulipas
# 4                  lic. Emilio portes gil         victoria       Tamaulipas
#
#   country fax    zip
# 0  Mexico   ?      ?
# 1  mexico   ?  78280
# 2  Mexico   ?  78000
# 3       ?   ?      ?
# 4  Mexico   ?      ?

# %%
chefmozGeo_r[chefmozGeo_r['placeID']==135040]
# Out:
# Empty DataFrame
# Columns: [placeID, latitude, longitude, the_geom_meter, address, city, state, country, fax, zip]
# Index: []

# %%
chefmozProfile_r.head()
# Out:
#    placeID            alcohol smoking_area dress_code      accessibility  \
# 0   134999  No_Alcohol_Served         none   informal   no_accessibility
# 1   132825  No_Alcohol_Served         none   informal  yes_accessibility
# 2   135106          Wine-Beer  only at bar   informal  yes_accessibility
# 3   132667  No_Alcohol_Served         none   informal  yes_accessibility
# 4   132613  No_Alcohol_Served    permitted   informal  yes_accessibility
#
#     price Rambience franchise    area other_services  \
# 0  medium  familiar       yes  closed           none
# 1     low  familiar       yes    open           none
# 2  medium  familiar       yes    open           none
# 3     low  familiar        no  closed           none
# 4  medium  familiar        no  closed           none
#
#                         Rpayment   Rpayment_accepts  Rcuisine   Rcuisine_Type  \
# 0                            NaN                NaN  Japanese           Asian
# 1                           cash               cash   Mexican  South_American
# 2  cash;VISA;MasterCard-Eurocard  cash; credictCard   Mexican  South_American
# 3                           cash               cash  Armenian     Middle East
# 4                           cash               cash   Mexican  South_American
#
#                        hours                  days parking_lot parking
# 0               11:00-21:00;  Diary_Days;Sat;;Sun;        none      no
# 1               09:00-12:00;  Diary_Days;Sat;;Sun;        none      no
# 2  18:00-23:30;;18:00-21:00;  Diary_Days;Sat;;Sun;        none      no
# 3               00:00-23:30;  Diary_Days;Sat;;Sun;        none      no
# 4  08:00-16:00;;07:00-16:00;  Diary_Days;Sat;;Sun;         yes     yes

# %%
chefmozProfile_r[chefmozProfile_r['placeID']==135040]
# Out:
# Empty DataFrame
# Columns: [placeID, alcohol, smoking_area, dress_code, accessibility, price, Rambience, franchise, area, other_services, Rpayment, Rpayment_accepts, Rcuisine, Rcuisine_Type, hours, days, parking_lot, parking]
# Index: []

# %%
rating_final_r.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   132825       2            2               2
# 2  U1077   135060       1            2               2
# 3  U1068   135104       1            1               2
# 4  U1068   132740       0            0               0

# %%
userChefmozRelation_r.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating          Upayment  \
# 0  U1077   135085       2            2               2              VISA
# 1  U1077   135085       2            2               2              cash
# 2  U1077   135085       2            2               2  bank_debit_cards
# 3  U1077   132825       2            2               2              VISA
# 4  U1077   132825       2            2               2              cash
#
#   Upayment_accepts Rcuisine   Rcuisine_Type
# 0      credictCard  Mexican  South_American
# 1             cash  Mexican  South_American
# 2      credictCard  Mexican  South_American
# 3      credictCard  Mexican  South_American
# 4             cash  Mexican  South_American

# %%
userGeo_r.head()
# Out:
#   userID   latitude   longitude
# 0  U1001  22.139997 -100.978803
# 1  U1002  22.150087 -100.983325
# 2  U1003  22.119847 -100.946527
# 3  U1004  18.867000  -99.183000
# 4  U1005  22.183477 -100.959891

# %%
userProfile_r.head()
# Out:
#   userID smoker     drink_level dress_preference ambience transport  \
# 0  U1001  false      abstemious         informal   family   on foot
# 1  U1002  false      abstemious         informal   family    public
# 2  U1003  false  social drinker           formal   family    public
# 3  U1004  false      abstemious         informal   family    public
# 4  U1005  false      abstemious    no preference   family    public
#
#   marital_status        hijos  religion      activity  \
# 0         single  independent      none       student
# 1         single  independent  Catholic       student
# 2         single  independent  Catholic       student
# 3         single  independent      none  professional
# 4         single  independent  Catholic       student
#
#                                        Rcuisine_Type          Upayment_accepts
# 0                                 ['North_American']                  ['cash']
# 1                                 ['South_American']                  ['cash']
# 2                                 ['South_American']                  ['cash']
# 3  ['Bakery', 'Breakfast', 'Asian', 'Contemporary...  ['cash', ' credictCard']
# 4                                 ['North_American']                  ['cash']
